# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x = df.iloc[:,3:13].values
y = df.iloc[:,13].values

# %%
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]],
#       shape=(10000, 10), dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(10000,))

# %%
x1 = LabelEncoder()
x[:,1] = x1.fit_transform(x[:,1])
x2 = LabelEncoder()
x[:,2] = x2.fit_transform(x[:,2])

# %%
x
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], shape=(10000, 10), dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,y,test_size = 0.2, random_state = 42)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# #TASK-1

# %%
model_A = Sequential()
model_A.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_A.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_A.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_A.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]
history_A = model_A.fit(x_train, y_train, validation_split=0.2, batch_size = 10, epochs = 25)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7936 - loss: 0.5019 - val_accuracy: 0.7987 - val_loss: 0.4329
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4380 - val_accuracy: 0.7987 - val_loss: 0.4303
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4329 - val_accuracy: 0.7987 - val_loss: 0.4222
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8055 - loss: 0.4277 - val_accuracy: 0.8294 - val_loss: 0.4198
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8219 - loss: 0.4251 - val_accuracy: 0.8331 - val_loss: 0.4179
# Epoch 6/25
# ...

# %%
model_B = Sequential()
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_B.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_B.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]
history_B = model_B.fit(x_train, y_train, validation_split=0.2, batch_size = 10, epochs = 25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7934 - loss: 0.4949 - val_accuracy: 0.7987 - val_loss: 0.4327
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4375 - val_accuracy: 0.7987 - val_loss: 0.4254
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7950 - loss: 0.4306 - val_accuracy: 0.8263 - val_loss: 0.4186
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8219 - loss: 0.4263 - val_accuracy: 0.8319 - val_loss: 0.4173
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8256 - loss: 0.4237 - val_accuracy: 0.8338 - val_loss: 0.4151
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 0.4219 - val_accuracy: 0.8369 - val_loss: 0.4155
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8334 - loss: 0.4201 - val_accuracy: 0.8356 - val_loss: 0.4159
# Epoch 8/25
# ...

# %%
model_C = Sequential()
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_C.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_C.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]
history_C = model_C.fit(x_train, y_train, validation_split=0.2, batch_size = 10, epochs = 25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7934 - loss: 0.5022 - val_accuracy: 0.7987 - val_loss: 0.4348
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4396 - val_accuracy: 0.7987 - val_loss: 0.4265
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7948 - loss: 0.4332 - val_accuracy: 0.8250 - val_loss: 0.4221
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8152 - loss: 0.4278 - val_accuracy: 0.8281 - val_loss: 0.4168
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8244 - loss: 0.4260 - val_accuracy: 0.8344 - val_loss: 0.4171
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8269 - loss: 0.4239 - val_accuracy: 0.8350 - val_loss: 0.4163
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8308 - loss: 0.4224 - val_accuracy: 0.8363 - val_loss: 0.4149
# Epoch 8/25
# ...

# %%
model_D = Sequential()
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_D.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
y_train[0]
history_D = model_D.fit(x_train, y_train, validation_split=0.2, batch_size = 10, epochs = 25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7934 - loss: 0.5065 - val_accuracy: 0.7987 - val_loss: 0.4366
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4357 - val_accuracy: 0.7987 - val_loss: 0.4242
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7975 - loss: 0.4242 - val_accuracy: 0.8281 - val_loss: 0.4101
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8258 - loss: 0.4099 - val_accuracy: 0.8306 - val_loss: 0.4011
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8305 - loss: 0.3987 - val_accuracy: 0.8313 - val_loss: 0.3904
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8408 - loss: 0.3890 - val_accuracy: 0.8425 - val_loss: 0.3838
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8431 - loss: 0.3840 - val_accuracy: 0.8456 - val_loss: 0.3817
# Epoch 8/25
# ...

# %%
print("Model A")
print("Training Accuracy:", history_A.history['accuracy'][-1])
print("Validation Accuracy:", history_A.history['val_accuracy'][-1])
print("Loss:", history_A.history['loss'][-1])

print("\nModel B")
print("Training Accuracy:", history_B.history['accuracy'][-1])
print("Validation Accuracy:", history_B.history['val_accuracy'][-1])
print("Loss:", history_B.history['loss'][-1])

print("\nModel C")
print("Training Accuracy:", history_C.history['accuracy'][-1])
print("Validation Accuracy:", history_C.history['val_accuracy'][-1])
print("Loss:", history_C.history['loss'][-1])

print("\nModel D")
print("Training Accuracy:", history_D.history['accuracy'][-1])
print("Validation Accuracy:", history_D.history['val_accuracy'][-1])
print("Loss:", history_D.history['loss'][-1])
# Out:
# Model A
# Training Accuracy: 0.8342187404632568
# Validation Accuracy: 0.8387500047683716
# Loss: 0.4075598418712616
#
# Model B
# Training Accuracy: 0.8362500071525574
# Validation Accuracy: 0.8337500095367432
# Loss: 0.4067179560661316
#
# Model C
# Training Accuracy: 0.8342187404632568
# Validation Accuracy: 0.8374999761581421
# Loss: 0.4084737300872803
#
# Model D
# Training Accuracy: 0.8560937643051147
# Validation Accuracy: 0.8581249713897705
# Loss: 0.35614898800849915

# %% [markdown]
# #TASK-2

# %%
import time

# %%
model_A = Sequential()
model_A.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_A.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model_A.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model_A.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_A.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history4 = model_A.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
end_time = time.time()

time4 = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7930 - loss: 0.5345 - val_accuracy: 0.7987 - val_loss: 0.4417
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4396 - val_accuracy: 0.7987 - val_loss: 0.4261
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8006 - loss: 0.4249 - val_accuracy: 0.8131 - val_loss: 0.4115
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8156 - loss: 0.4041 - val_accuracy: 0.8206 - val_loss: 0.3884
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8397 - loss: 0.3799 - val_accuracy: 0.8500 - val_loss: 0.3729
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3667 - val_accuracy: 0.8512 - val_loss: 0.3650
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3611 - val_accuracy: 0.8506 - val_loss: 0.3610
# Epoch 8/25
# ...

# %%
loss4, acc4 = model_A.evaluate(x_test, y_test)

print("Accuracy :", acc4)
print("Loss :", loss4)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8605 - loss: 0.3477
# Accuracy : 0.8604999780654907
# Loss : 0.3476795256137848

# %%
model_B = Sequential()
model_B.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_B.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model_B.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model_B.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_B.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history8 = model_B.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
end_time = time.time()

time8 = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7931 - loss: 0.5020 - val_accuracy: 0.7987 - val_loss: 0.4322
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4390 - val_accuracy: 0.7987 - val_loss: 0.4282
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4347 - val_accuracy: 0.7987 - val_loss: 0.4244
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8014 - loss: 0.4301 - val_accuracy: 0.8294 - val_loss: 0.4213
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8213 - loss: 0.4271 - val_accuracy: 0.8331 - val_loss: 0.4178
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8227 - loss: 0.4244 - val_accuracy: 0.8338 - val_loss: 0.4176
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8280 - loss: 0.4229 - val_accuracy: 0.8356 - val_loss: 0.4163
# Epoch 8/25
# ...

# %%
loss8, acc8 = model_B.evaluate(x_test, y_test)

print("Accuracy :", acc8)
print("Loss :", loss8)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8430 - loss: 0.3917
# Accuracy : 0.8429999947547913
# Loss : 0.3917495310306549

# %%
model_C = Sequential()
model_C.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_C.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model_C.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model_C.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_C.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history16 = model_C.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
end_time = time.time()

time16 = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7931 - loss: 0.4773 - val_accuracy: 0.7987 - val_loss: 0.4280
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7981 - loss: 0.4324 - val_accuracy: 0.8300 - val_loss: 0.4206
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8273 - loss: 0.4209 - val_accuracy: 0.8338 - val_loss: 0.4111
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8327 - loss: 0.4117 - val_accuracy: 0.8319 - val_loss: 0.4065
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8347 - loss: 0.4062 - val_accuracy: 0.8363 - val_loss: 0.4043
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8378 - loss: 0.4028 - val_accuracy: 0.8288 - val_loss: 0.4050
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8348 - loss: 0.4024 - val_accuracy: 0.8363 - val_loss: 0.4029
# Epoch 8/25
# ...

# %%
loss16, acc16 = model_C.evaluate(x_test, y_test)

print("Accuracy :", acc16)
print("Loss :", loss16)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8615 - loss: 0.3433
# Accuracy : 0.8615000247955322
# Loss : 0.34334444999694824

# %%
model_D = Sequential()
model_D.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_D.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model_D.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_D.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history4 = model_D.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
end_time = time.time()

time32 = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7948 - loss: 0.4594 - val_accuracy: 0.8087 - val_loss: 0.4105
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8378 - loss: 0.4001 - val_accuracy: 0.8556 - val_loss: 0.3696
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8562 - loss: 0.3642 - val_accuracy: 0.8550 - val_loss: 0.3573
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8581 - loss: 0.3541 - val_accuracy: 0.8444 - val_loss: 0.3686
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8584 - loss: 0.3509 - val_accuracy: 0.8581 - val_loss: 0.3464
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8591 - loss: 0.3462 - val_accuracy: 0.8531 - val_loss: 0.3459
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8611 - loss: 0.3426 - val_accuracy: 0.8587 - val_loss: 0.3441
# Epoch 8/25
# ...

# %%
loss32, acc32 = model_D.evaluate(x_test, y_test)

print("Accuracy :", acc32)
print("Loss :", loss32)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3426
# Accuracy : 0.8619999885559082
# Loss : 0.3425525426864624

# %%
model_E = Sequential()
model_E.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_E.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu'))
model_E.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu'))
model_E.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model_E.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history4 = model_E.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
end_time = time.time()

time64 = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8005 - loss: 0.4550 - val_accuracy: 0.8294 - val_loss: 0.4199
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8370 - loss: 0.4082 - val_accuracy: 0.8413 - val_loss: 0.3810
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8500 - loss: 0.3723 - val_accuracy: 0.8531 - val_loss: 0.3524
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8536 - loss: 0.3570 - val_accuracy: 0.8569 - val_loss: 0.3540
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8587 - loss: 0.3500 - val_accuracy: 0.8587 - val_loss: 0.3417
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8591 - loss: 0.3467 - val_accuracy: 0.8581 - val_loss: 0.3443
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8612 - loss: 0.3417 - val_accuracy: 0.8562 - val_loss: 0.3415
# Epoch 8/25
# ...

# %%
loss64, acc64 = model_E.evaluate(x_test, y_test)

print("Accuracy :", acc64)
print("Loss :", loss64)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3428
# Accuracy : 0.8619999885559082
# Loss : 0.3427583575248718

# %%
table = pd.DataFrame({
    "Hidden Neurons":[4,8,16,32,64],
    "Accuracy":[acc4,acc8,acc16,acc32,acc64],
    "Loss":[loss4,loss8,loss16,loss32,loss64],
    "Training Time":[time4,time8,time16,time32,time64]
})

print(table)
# Out:
#    Hidden Neurons  Accuracy      Loss  Training Time
# 0               4    0.8605  0.347680      33.861604
# 1               8    0.8430  0.391750      34.450924
# 2              16    0.8615  0.343344      38.698772
# 3              32    0.8620  0.342553      44.022482
# 4              64    0.8620  0.342758      42.638279

# %% [markdown]
# #TASK-3

# %%
model_A = Sequential()
model_A.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model_A.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_A.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model_A.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_A.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_relu = model_A.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7933 - loss: 0.5008 - val_accuracy: 0.7987 - val_loss: 0.4347
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4392 - val_accuracy: 0.7987 - val_loss: 0.4283
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4334 - val_accuracy: 0.7987 - val_loss: 0.4228
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8028 - loss: 0.4284 - val_accuracy: 0.8288 - val_loss: 0.4189
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8202 - loss: 0.4251 - val_accuracy: 0.8350 - val_loss: 0.4188
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8259 - loss: 0.4230 - val_accuracy: 0.8344 - val_loss: 0.4162
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8291 - loss: 0.4207 - val_accuracy: 0.8356 - val_loss: 0.4132
# Epoch 8/25
# ...

# %%
loss_relu, acc_relu = model_A.evaluate(x_test, y_test)
epochs_relu = len(history_relu.history['loss'])
print("Accuracy:", acc_relu)
print("Loss:", loss_relu)
print("Epochs:", epochs_relu)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8390 - loss: 0.3918
# Accuracy: 0.8389999866485596
# Loss: 0.3917977809906006
# Epochs: 25

# %%
model_B = Sequential()
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'sigmoid', input_dim = 10))
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'sigmoid'))
model_B.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'sigmoid'))
model_B.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_B.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_sigmoid = model_B.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7894 - loss: 0.5434 - val_accuracy: 0.7987 - val_loss: 0.4994
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.5049 - val_accuracy: 0.7987 - val_loss: 0.4954
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.5007 - val_accuracy: 0.7987 - val_loss: 0.4914
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4950 - val_accuracy: 0.7987 - val_loss: 0.4835
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4872 - val_accuracy: 0.7987 - val_loss: 0.4752
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4769 - val_accuracy: 0.7987 - val_loss: 0.4659
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4673 - val_accuracy: 0.7987 - val_loss: 0.4548
# Epoch 8/25
# ...

# %%
loss_sigmoid, acc_sigmoid = model_B.evaluate(x_test, y_test)
epochs_sigmoid = len(history_sigmoid.history['loss'])
print("Accuracy:", acc_sigmoid)
print("Loss:", loss_sigmoid)
print("Epochs:", epochs_sigmoid)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8035 - loss: 0.4239
# Accuracy: 0.8034999966621399
# Loss: 0.4238509237766266
# Epochs: 25

# %%
model_C = Sequential()
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'tanh', input_dim = 10))
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'tanh'))
model_C.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'tanh'))
model_C.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'tanh'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_C.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_tanh = model_C.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7934 - loss: 0.5634 - val_accuracy: 0.7987 - val_loss: 0.4660
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7933 - loss: 0.4603 - val_accuracy: 0.7987 - val_loss: 0.4576
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7931 - loss: 0.4683 - val_accuracy: 0.7994 - val_loss: 0.4668
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4692 - val_accuracy: 0.7987 - val_loss: 0.4666
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7933 - loss: 0.4662 - val_accuracy: 0.7987 - val_loss: 0.4481
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7933 - loss: 0.4645 - val_accuracy: 0.7987 - val_loss: 0.4542
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4661 - val_accuracy: 0.7987 - val_loss: 0.4538
# Epoch 8/25
# ...

# %%
loss_tanh, acc_tanh = model_C.evaluate(x_test, y_test)
epochs_tanh = len(history_tanh.history['loss'])
print("Accuracy:", acc_tanh)
print("Loss:", loss_tanh)
print("Epochs:", epochs_tanh)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8050 - loss: 0.4428
# Accuracy: 0.8050000071525574
# Loss: 0.44276222586631775
# Epochs: 25

# %%
model_D = Sequential()
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'elu', input_dim = 10))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'elu'))
model_D.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'elu'))
model_D.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'elu'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_D.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_elu = model_D.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7934 - loss: 0.9004 - val_accuracy: 0.7987 - val_loss: 0.6348
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.5090 - val_accuracy: 0.7994 - val_loss: 0.4521
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7916 - loss: 0.4620 - val_accuracy: 0.8031 - val_loss: 0.4554
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7909 - loss: 0.4626 - val_accuracy: 0.8025 - val_loss: 0.4669
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7917 - loss: 0.4625 - val_accuracy: 0.8019 - val_loss: 0.4700
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7917 - loss: 0.4601 - val_accuracy: 0.8012 - val_loss: 0.4435
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7923 - loss: 0.4642 - val_accuracy: 0.8012 - val_loss: 0.4599
# Epoch 8/25
# ...

# %%
loss_elu, acc_elu = model_D.evaluate(x_test, y_test)
epochs_elu = len(history_elu.history['loss'])
print("Accuracy:", acc_elu)
print("Loss:", loss_elu)
print("Epochs:", epochs_elu)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8390 - loss: 0.4094
# Accuracy: 0.8389999866485596
# Loss: 0.40942293405532837
# Epochs: 25

# %%
from keras.layers import LeakyReLU

# %%
model_E = Sequential()
model_E.add(Dense(units=6, kernel_initializer='uniform', input_dim=10))
model_E.add(LeakyReLU())

model_E.add(Dense(units=6, kernel_initializer='uniform'))
model_E.add(LeakyReLU())

model_E.add(Dense(units=6, kernel_initializer='uniform'))
model_E.add(LeakyReLU())

model_E.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_E.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_Lelu = model_E.fit(x_train, y_train, validation_split=0.2, batch_size=10, epochs=25)
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7920 - loss: 0.4935 - val_accuracy: 0.8019 - val_loss: 0.4297
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7950 - loss: 0.4376 - val_accuracy: 0.8188 - val_loss: 0.4267
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8138 - loss: 0.4329 - val_accuracy: 0.8288 - val_loss: 0.4185
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8288 - loss: 0.4249 - val_accuracy: 0.8331 - val_loss: 0.4140
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8323 - loss: 0.4191 - val_accuracy: 0.8350 - val_loss: 0.4095
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8355 - loss: 0.4163 - val_accuracy: 0.8344 - val_loss: 0.4068
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8347 - loss: 0.4149 - val_accuracy: 0.8344 - val_loss: 0.4061
# Epoch 8/25
# ...

# %%
loss_Lelu, acc_Lelu = model_E.evaluate(x_test, y_test)
epochs_Lelu = len(history_Lelu.history['loss'])
print("Accuracy:", acc_Lelu)
print("Loss:", loss_Lelu)
print("Epochs:", epochs_Lelu)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8420 - loss: 0.3922
# Accuracy: 0.8420000076293945
# Loss: 0.39220285415649414
# Epochs: 25

# %%
table = pd.DataFrame({
    "Activation Function": ["ReLU", "Sigmoid", "Tanh", "ELU", "Leaky ReLU"],
    "Accuracy": [acc_relu, acc_sigmoid, acc_tanh, acc_elu, acc_Lelu],
    "Loss": [loss_relu, loss_sigmoid, loss_tanh, loss_elu, loss_Lelu],
    "Epochs": [epochs_relu, epochs_sigmoid, epochs_tanh, epochs_elu, epochs_Lelu]
})

print(table)
# Out:
#   Activation Function  Accuracy      Loss  Epochs
# 0                ReLU    0.8390  0.391798      25
# 1             Sigmoid    0.8035  0.423851      25
# 2                Tanh    0.8050  0.442762      25
# 3                 ELU    0.8390  0.409423      25
# 4          Leaky ReLU    0.8420  0.392203      25

# %% [markdown]
# #TASK-4

# %%
model_A = Sequential()
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=10))
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))
model_A.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_A.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_uniform = model_A.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_uniform = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8353 - loss: 0.4072 - val_accuracy: 0.8375 - val_loss: 0.4052
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8353 - loss: 0.4064 - val_accuracy: 0.8331 - val_loss: 0.4095
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8358 - loss: 0.4068 - val_accuracy: 0.8381 - val_loss: 0.4017
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8341 - loss: 0.4057 - val_accuracy: 0.8363 - val_loss: 0.4016
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8356 - loss: 0.4062 - val_accuracy: 0.8356 - val_loss: 0.4017
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8347 - loss: 0.4057 - val_accuracy: 0.8363 - val_loss: 0.4010
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8347 - loss: 0.4058 - val_accuracy: 0.8356 - val_loss: 0.4015
# Epoch 8/25
# ...

# %%
loss_uniform, acc_uniform = model_A.evaluate(x_test, y_test)
initial_loss_uniform = history_uniform.history['loss'][0]
print("Initial Loss :", initial_loss_uniform)
print("Final Accuracy :", acc_uniform)
print("Training Time :", time_uniform)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8410 - loss: 0.3884
# Initial Loss : 0.40724629163742065
# Final Accuracy : 0.8410000205039978
# Training Time : 53.070817708969116

# %%
model_B = Sequential()
model_B.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', input_dim=10))
model_B.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
model_B.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
model_B.add(Dense(units=1, kernel_initializer='he_uniform', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_B.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_he_uniform = model_B.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_he_uniform = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7822 - loss: 0.5171 - val_accuracy: 0.7987 - val_loss: 0.4737
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4675 - val_accuracy: 0.7987 - val_loss: 0.4494
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4508 - val_accuracy: 0.7987 - val_loss: 0.4372
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4426 - val_accuracy: 0.8019 - val_loss: 0.4309
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8069 - loss: 0.4345 - val_accuracy: 0.8225 - val_loss: 0.4250
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8092 - loss: 0.4291 - val_accuracy: 0.8244 - val_loss: 0.4212
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8178 - loss: 0.4223 - val_accuracy: 0.8213 - val_loss: 0.4183
# Epoch 8/25
# ...

# %%
loss_he_uniform, acc_he_uniform = model_B.evaluate(x_test, y_test)
initial_loss_he_uniform = history_he_uniform.history['loss'][0]
print("Initial Loss :", initial_loss_he_uniform)
print("Final Accuracy :", acc_he_uniform)
print("Training Time :", time_he_uniform)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8430 - loss: 0.3775
# Initial Loss : 0.5171133279800415
# Final Accuracy : 0.8429999947547913
# Training Time : 44.48523712158203

# %%
model_C = Sequential()
model_C.add(Dense(units=6, kernel_initializer='he_normal', activation='relu', input_dim=10))
model_C.add(Dense(units=6, kernel_initializer='he_normal', activation='relu'))
model_C.add(Dense(units=6, kernel_initializer='he_normal', activation='relu'))
model_C.add(Dense(units=1, kernel_initializer='he_normal', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_C.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_he_normal = model_C.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_he_normal = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7397 - loss: 0.5576 - val_accuracy: 0.7981 - val_loss: 0.4781
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7928 - loss: 0.4786 - val_accuracy: 0.7981 - val_loss: 0.4553
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7931 - loss: 0.4605 - val_accuracy: 0.7981 - val_loss: 0.4430
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7955 - loss: 0.4472 - val_accuracy: 0.7994 - val_loss: 0.4365
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8039 - loss: 0.4365 - val_accuracy: 0.8087 - val_loss: 0.4311
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8153 - loss: 0.4259 - val_accuracy: 0.8213 - val_loss: 0.4225
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8259 - loss: 0.4157 - val_accuracy: 0.8269 - val_loss: 0.4121
# Epoch 8/25
# ...

# %%
loss_he_normal, acc_he_normal = model_C.evaluate(x_test, y_test)
initial_loss_he_normal = history_he_normal.history['loss'][0]
print("Initial Loss :", initial_loss_he_normal)
print("Final Accuracy :", acc_he_normal)
print("Training Time :", time_he_normal)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8615 - loss: 0.3423
# Initial Loss : 0.5576272010803223
# Final Accuracy : 0.8615000247955322
# Training Time : 55.55522346496582

# %%
model_D = Sequential()
model_D.add(Dense(units=6, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
model_D.add(Dense(units=6, kernel_initializer='glorot_uniform', activation='relu'))
model_D.add(Dense(units=6, kernel_initializer='glorot_uniform', activation='relu'))
model_D.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
model_D.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_glorot_uniform = model_D.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_glorot_uniform = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7672 - loss: 0.5755 - val_accuracy: 0.8025 - val_loss: 0.4841
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8080 - loss: 0.4683 - val_accuracy: 0.8238 - val_loss: 0.4427
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8225 - loss: 0.4427 - val_accuracy: 0.8200 - val_loss: 0.4318
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8222 - loss: 0.4309 - val_accuracy: 0.8188 - val_loss: 0.4219
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8242 - loss: 0.4198 - val_accuracy: 0.8263 - val_loss: 0.4109
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8284 - loss: 0.4098 - val_accuracy: 0.8288 - val_loss: 0.4021
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8328 - loss: 0.4000 - val_accuracy: 0.8338 - val_loss: 0.3988
# Epoch 8/25
# ...

# %%
loss_glorot_uniform, acc_glorot_uniform = model_D.evaluate(x_test, y_test)
initial_loss_glorot_uniform = history_glorot_uniform.history['loss'][0]
print("Initial Loss :", initial_loss_glorot_uniform)
print("Final Accuracy :", acc_glorot_uniform)
print("Training Time :", time_glorot_uniform)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8535 - loss: 0.3450
# Initial Loss : 0.5755100250244141
# Final Accuracy : 0.8535000085830688
# Training Time : 52.74007964134216

# %%
model_E = Sequential()
model_E.add(Dense(units=6, kernel_initializer='glorot_normal', activation='relu', input_dim=10))
model_E.add(Dense(units=6, kernel_initializer='glorot_normal', activation='relu'))
model_E.add(Dense(units=6, kernel_initializer='glorot_normal', activation='relu'))
model_E.add(Dense(units=1, kernel_initializer='glorot_normal', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_E.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_glorot_normal = model_E.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_glorot_normal = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7892 - loss: 0.5053 - val_accuracy: 0.7987 - val_loss: 0.4433
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4374 - val_accuracy: 0.7987 - val_loss: 0.4264
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4238 - val_accuracy: 0.7987 - val_loss: 0.4186
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8027 - loss: 0.4157 - val_accuracy: 0.8238 - val_loss: 0.4134
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8181 - loss: 0.4093 - val_accuracy: 0.8231 - val_loss: 0.4062
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8222 - loss: 0.3999 - val_accuracy: 0.8319 - val_loss: 0.3976
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8331 - loss: 0.3915 - val_accuracy: 0.8344 - val_loss: 0.3947
# Epoch 8/25
# ...

# %%
loss_glorot_normal, acc_glorot_normal = model_E.evaluate(x_test, y_test)
initial_loss_glorot_normal = history_glorot_normal.history['loss'][0]
print("Initial Loss :", initial_loss_glorot_normal)
print("Final Accuracy :", acc_glorot_normal)
print("Training Time :", time_glorot_normal)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8550 - loss: 0.3521
# Initial Loss : 0.5052979588508606
# Final Accuracy : 0.8550000190734863
# Training Time : 48.08363127708435

# %%
model_F = Sequential()
model_F.add(Dense(units=6, kernel_initializer='random_normal', activation='relu', input_dim=10))
model_F.add(Dense(units=6, kernel_initializer='random_normal', activation='relu'))
model_F.add(Dense(units=6, kernel_initializer='random_normal', activation='relu'))
model_F.add(Dense(units=1, kernel_initializer='random_normal', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_F.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history_random_normal = model_F.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=25)
end_time = time.time()

time_random_normal = end_time - start_time
# Out:
# Epoch 1/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7936 - loss: 0.5009 - val_accuracy: 0.7987 - val_loss: 0.4382
# Epoch 2/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4422 - val_accuracy: 0.7987 - val_loss: 0.4342
# Epoch 3/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4392 - val_accuracy: 0.7987 - val_loss: 0.4312
# Epoch 4/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4372 - val_accuracy: 0.7987 - val_loss: 0.4289
# Epoch 5/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4354 - val_accuracy: 0.7987 - val_loss: 0.4275
# Epoch 6/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8087 - loss: 0.4315 - val_accuracy: 0.8344 - val_loss: 0.4225
# Epoch 7/25
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8270 - loss: 0.4253 - val_accuracy: 0.8338 - val_loss: 0.4158
# Epoch 8/25
# ...

# %%
loss_random_normal, acc_random_normal = model_F.evaluate(x_test, y_test)
initial_loss_random_normal = history_random_normal.history['loss'][0]
print("Initial Loss :", initial_loss_random_normal)
print("Final Accuracy :", acc_random_normal)
print("Training Time :", time_random_normal)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8435 - loss: 0.3861
# Initial Loss : 0.5009397864341736
# Final Accuracy : 0.843500018119812
# Training Time : 47.49407768249512

# %%
table = pd.DataFrame({
    "Initializer": ["Uniform","He Uniform","He Normal","Glorot Uniform","Glorot Normal","Random Normal"],
    "Initial Loss": [initial_loss_uniform,initial_loss_he_uniform,initial_loss_he_normal,initial_loss_glorot_uniform,initial_loss_glorot_normal,initial_loss_random_normal],
    "Final Accuracy": [acc_uniform,acc_he_uniform,acc_he_normal,acc_glorot_uniform,acc_glorot_normal,acc_random_normal],
    "Training Time": [time_uniform,time_he_uniform,time_he_normal,time_glorot_uniform,time_glorot_normal,time_random_normal]
})

print(table)
# Out:
#       Initializer  Initial Loss  Final Accuracy  Training Time
# 0         Uniform      0.407246          0.8410      53.070818
# 1      He Uniform      0.517113          0.8430      44.485237
# 2       He Normal      0.557627          0.8615      55.555223
# 3  Glorot Uniform      0.575510          0.8535      52.740080
# 4   Glorot Normal      0.505298          0.8550      48.083631
# 5   Random Normal      0.500940          0.8435      47.494078

# %% [markdown]
# #TASK-5

# %%
model_A = Sequential()
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='sigmoid', input_dim=10))
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='sigmoid'))
model_A.add(Dense(units=6, kernel_initializer='uniform', activation='sigmoid'))
model_A.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_A.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

start_time = time.time()
history = model_A.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7847 - loss: 0.5430 - val_accuracy: 0.7987 - val_loss: 0.4988
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.5048 - val_accuracy: 0.7987 - val_loss: 0.4951
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7934 - loss: 0.5007 - val_accuracy: 0.7987 - val_loss: 0.4906
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7934 - loss: 0.4949 - val_accuracy: 0.7987 - val_loss: 0.4842
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7934 - loss: 0.4867 - val_accuracy: 0.7987 - val_loss: 0.4745
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7934 - loss: 0.4769 - val_accuracy: 0.7987 - val_loss: 0.4639
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4666 - val_accuracy: 0.7987 - val_loss: 0.4540
# Epoch 8/15
# ...

# %% [markdown]
# Sigmoid is used for binary classification because it converts the output into a probability between 0 and 1.
#
# Softmax is used for multiclass classification problems where there are three or more classes.Softmax is used for multiclass classification problems where there are three or more classes.
#
# Linear activation is used for regression problems where the output is a continuous numerical value.

# %% [markdown]
# #TASK-6

# %%
model_A = Sequential()
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_A.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import time
model_A.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_adam = model_A.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time_adam = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8325 - loss: 0.4194 - val_accuracy: 0.8338 - val_loss: 0.4131
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8331 - loss: 0.4184 - val_accuracy: 0.8325 - val_loss: 0.4119
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8328 - loss: 0.4172 - val_accuracy: 0.8331 - val_loss: 0.4120
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8338 - loss: 0.4165 - val_accuracy: 0.8331 - val_loss: 0.4109
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8339 - loss: 0.4156 - val_accuracy: 0.8344 - val_loss: 0.4102
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8320 - loss: 0.4146 - val_accuracy: 0.8344 - val_loss: 0.4116
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8334 - loss: 0.4148 - val_accuracy: 0.8344 - val_loss: 0.4107
# Epoch 8/15
# ...

# %%
loss_adam, acc_adam = model_A.evaluate(x_test, y_test)
print("Accuracy :", acc_adam)
print("Loss :", loss_adam)
print("Training Time :", time_adam)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8375 - loss: 0.3926
# Accuracy : 0.8374999761581421
# Loss : 0.3925594091415405
# Training Time : 35.09023332595825

# %%
model_B = Sequential()
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_B.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_B.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_sgd = model_B.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time_sgd = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.5706 - val_accuracy: 0.7987 - val_loss: 0.5171
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7934 - loss: 0.5145 - val_accuracy: 0.7987 - val_loss: 0.5044
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.5100 - val_accuracy: 0.7987 - val_loss: 0.5026
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.5095 - val_accuracy: 0.7987 - val_loss: 0.5023
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.5095 - val_accuracy: 0.7987 - val_loss: 0.5023
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.5094 - val_accuracy: 0.7987 - val_loss: 0.5022
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.5094 - val_accuracy: 0.7987 - val_loss: 0.5022
# Epoch 8/15
# ...

# %%
loss_sgd, acc_sgd = model_B.evaluate(x_test, y_test)
print("Accuracy :", acc_sgd)
print("Loss :", loss_sgd)
print("Training Time :", time_sgd)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8035 - loss: 0.4959
# Accuracy : 0.8034999966621399
# Loss : 0.4958837628364563
# Training Time : 29.15122079849243

# %%
model_C = Sequential()
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_C.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_C.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_rmsprop = model_C.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time_rmsprop = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7933 - loss: 0.5352 - val_accuracy: 0.7987 - val_loss: 0.4443
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4400 - val_accuracy: 0.7987 - val_loss: 0.4246
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.4304 - val_accuracy: 0.7987 - val_loss: 0.4170
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7987 - loss: 0.4238 - val_accuracy: 0.8313 - val_loss: 0.4115
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8277 - loss: 0.4153 - val_accuracy: 0.8406 - val_loss: 0.4033
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8375 - loss: 0.4027 - val_accuracy: 0.8425 - val_loss: 0.3915
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8469 - loss: 0.3881 - val_accuracy: 0.8487 - val_loss: 0.3809
# Epoch 8/15
# ...

# %%
loss_rmsprop, acc_rmsprop = model_C.evaluate(x_test, y_test)
print("Accuracy :", acc_rmsprop)
print("Loss :", loss_rmsprop)
print("Training Time :", time_rmsprop)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8595 - loss: 0.3460
# Accuracy : 0.859499990940094
# Loss : 0.34596574306488037
# Training Time : 31.807848691940308

# %%
model_D = Sequential()
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_D.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_D.compile(optimizer='adagrad',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_adagrad = model_D.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time_adagrad = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7936 - loss: 0.6847 - val_accuracy: 0.7987 - val_loss: 0.6799
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.6771 - val_accuracy: 0.7987 - val_loss: 0.6740
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.6719 - val_accuracy: 0.7987 - val_loss: 0.6691
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.6672 - val_accuracy: 0.7987 - val_loss: 0.6644
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.6627 - val_accuracy: 0.7987 - val_loss: 0.6598
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.6582 - val_accuracy: 0.7987 - val_loss: 0.6552
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7934 - loss: 0.6537 - val_accuracy: 0.7987 - val_loss: 0.6507
# Epoch 8/15
# ...

# %%
loss_adagrad, acc_adagrad = model_D.evaluate(x_test, y_test)
print("Accuracy :", acc_adagrad)
print("Loss :", loss_adagrad)
print("Training Time :", time_adagrad)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8035 - loss: 0.6174
# Accuracy : 0.8034999966621399
# Loss : 0.6174261569976807
# Training Time : 30.353293657302856

# %%
model_E = Sequential()
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_E.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_E.compile(optimizer='nadam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_nadam = model_E.fit(x_train,y_train,validation_split=0.2,batch_size=10,epochs=15)
end_time = time.time()

time_nadam = end_time - start_time
# Out:
# Epoch 1/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7931 - loss: 0.4969 - val_accuracy: 0.7987 - val_loss: 0.4334
# Epoch 2/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4388 - val_accuracy: 0.7987 - val_loss: 0.4273
# Epoch 3/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7934 - loss: 0.4328 - val_accuracy: 0.7987 - val_loss: 0.4210
# Epoch 4/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8120 - loss: 0.4276 - val_accuracy: 0.8300 - val_loss: 0.4177
# Epoch 5/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8239 - loss: 0.4246 - val_accuracy: 0.8319 - val_loss: 0.4173
# Epoch 6/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8280 - loss: 0.4229 - val_accuracy: 0.8338 - val_loss: 0.4145
# Epoch 7/15
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8291 - loss: 0.4210 - val_accuracy: 0.8350 - val_loss: 0.4137
# Epoch 8/15
# ...

# %%
loss_nadam, acc_nadam = model_E.evaluate(x_test, y_test)
print("Accuracy :", acc_nadam)
print("Loss :", loss_nadam)
print("Training Time :", time_nadam)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3948
# Accuracy : 0.8395000100135803
# Loss : 0.39481693506240845
# Training Time : 33.42649745941162

# %%
table = pd.DataFrame({
    "Optimizer": ["Adam", "SGD", "RMSprop", "Adagrad", "Nadam"],
    "Accuracy": [acc_adam,acc_sgd,acc_rmsprop,acc_adagrad,acc_nadam],
    "Loss": [loss_adam,loss_sgd,loss_rmsprop,loss_adagrad,loss_nadam],
    "Training Time": [time_adam,time_sgd,time_rmsprop,time_adagrad,time_nadam]
})

print(table)
# Out:
#   Optimizer  Accuracy      Loss  Training Time
# 0      Adam    0.8375  0.392559      35.090233
# 1       SGD    0.8035  0.495884      29.151221
# 2   RMSprop    0.8595  0.345966      31.807849
# 3   Adagrad    0.8035  0.617426      30.353294
# 4     Nadam    0.8395  0.394817      33.426497

# %% [markdown]
# #TASK-8

# %%
model_A = Sequential()
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_A.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_A.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_batch8 = model_A.fit(x_train,y_train,validation_split=0.2,batch_size=8,epochs=15)
end_time = time.time()

time_batch8 = end_time - start_time
# Out:
# Epoch 1/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.7934 - loss: 0.4913 - val_accuracy: 0.7987 - val_loss: 0.4326
# Epoch 2/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7934 - loss: 0.4358 - val_accuracy: 0.7987 - val_loss: 0.4237
# Epoch 3/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8045 - loss: 0.4289 - val_accuracy: 0.8294 - val_loss: 0.4189
# Epoch 4/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8263 - loss: 0.4253 - val_accuracy: 0.8338 - val_loss: 0.4187
# Epoch 5/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8286 - loss: 0.4232 - val_accuracy: 0.8338 - val_loss: 0.4161
# Epoch 6/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8303 - loss: 0.4215 - val_accuracy: 0.8288 - val_loss: 0.4147
# Epoch 7/15
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8319 - loss: 0.4199 - val_accuracy: 0.8319 - val_loss: 0.4143
# Epoch 8/15
# ...

# %%
loss_batch8, acc_batch8 = model_A.evaluate(x_test, y_test)

print("Accuracy :", acc_batch8)
print("Loss :", loss_batch8)
print("Training Time :", time_batch8)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8380 - loss: 0.3996
# Accuracy : 0.8379999995231628
# Loss : 0.3995998501777649
# Training Time : 43.966745376586914

# %%
model_B = Sequential()
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_B.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_batch16 = model_B.fit(x_train,y_train,validation_split=0.2,batch_size=16,epochs=15)
end_time = time.time()

time_batch16 = end_time - start_time
# Out:
# Epoch 1/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7934 - loss: 0.5256 - val_accuracy: 0.7987 - val_loss: 0.4371
# Epoch 2/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4400 - val_accuracy: 0.7987 - val_loss: 0.4292
# Epoch 3/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4334 - val_accuracy: 0.7987 - val_loss: 0.4244
# Epoch 4/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7994 - loss: 0.4295 - val_accuracy: 0.8200 - val_loss: 0.4194
# Epoch 5/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8155 - loss: 0.4260 - val_accuracy: 0.8344 - val_loss: 0.4169
# Epoch 6/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8253 - loss: 0.4245 - val_accuracy: 0.8363 - val_loss: 0.4166
# Epoch 7/15
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8266 - loss: 0.4229 - val_accuracy: 0.8369 - val_loss: 0.4155
# Epoch 8/15
# ...

# %%
loss_batch16, acc_batch16 = model_B.evaluate(x_test, y_test)

print("Accuracy :", acc_batch16)
print("Loss :", loss_batch16)
print("Training Time :", time_batch16)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8410 - loss: 0.3980
# Accuracy : 0.8410000205039978
# Loss : 0.3979767858982086
# Training Time : 29.750303268432617

# %%
model_C = Sequential()
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_C.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_C.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_C.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_batch32 = model_C.fit(x_train,y_train,validation_split=0.2,batch_size=32,epochs=15)
end_time = time.time()

time_batch32 = end_time - start_time
# Out:
# Epoch 1/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7934 - loss: 0.5897 - val_accuracy: 0.7987 - val_loss: 0.4492
# Epoch 2/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4498 - val_accuracy: 0.7987 - val_loss: 0.4349
# Epoch 3/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4419 - val_accuracy: 0.7987 - val_loss: 0.4322
# Epoch 4/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7934 - loss: 0.4390 - val_accuracy: 0.7987 - val_loss: 0.4299
# Epoch 5/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7934 - loss: 0.4361 - val_accuracy: 0.7987 - val_loss: 0.4270
# Epoch 6/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4332 - val_accuracy: 0.7987 - val_loss: 0.4243
# Epoch 7/15
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.4303 - val_accuracy: 0.7987 - val_loss: 0.4207
# Epoch 8/15
# ...

# %%
loss_batch32, acc_batch32 = model_C.evaluate(x_test, y_test)

print("Accuracy :", acc_batch32)
print("Loss :", loss_batch32)
print("Training Time :", time_batch32)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8330 - loss: 0.4047
# Accuracy : 0.8330000042915344
# Loss : 0.4047394394874573
# Training Time : 14.169676542282104

# %%
model_D = Sequential()
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_D.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_D.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_batch64 = model_D.fit(x_train,y_train,validation_split=0.2,batch_size=64,epochs=15)
end_time = time.time()

time_batch64 = end_time - start_time
# Out:
# Epoch 1/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7934 - loss: 0.6683 - val_accuracy: 0.7987 - val_loss: 0.6203
# Epoch 2/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7934 - loss: 0.5216 - val_accuracy: 0.7987 - val_loss: 0.4520
# Epoch 3/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7934 - loss: 0.4529 - val_accuracy: 0.7987 - val_loss: 0.4416
# Epoch 4/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.4457 - val_accuracy: 0.7987 - val_loss: 0.4371
# Epoch 5/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7934 - loss: 0.4419 - val_accuracy: 0.7987 - val_loss: 0.4346
# Epoch 6/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7934 - loss: 0.4394 - val_accuracy: 0.7987 - val_loss: 0.4334
# Epoch 7/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7934 - loss: 0.4381 - val_accuracy: 0.7987 - val_loss: 0.4321
# Epoch 8/15
# ...

# %%
loss_batch64, acc_batch64 = model_D.evaluate(x_test, y_test)

print("Accuracy :", acc_batch64)
print("Loss :", loss_batch64)
print("Training Time :", time_batch64)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8155 - loss: 0.4103
# Accuracy : 0.815500020980835
# Loss : 0.4103381037712097
# Training Time : 10.273008108139038

# %%
model_E = Sequential()
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_E.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model_E.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# d:\Ethnotech\Deep Learning\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_E.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history_batch128 = model_E.fit(x_train,y_train,validation_split=0.2,batch_size=128,epochs=15)
end_time = time.time()

time_batch128 = end_time - start_time
# Out:
# Epoch 1/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7931 - loss: 0.6849 - val_accuracy: 0.7987 - val_loss: 0.6743
# Epoch 2/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7934 - loss: 0.6557 - val_accuracy: 0.7987 - val_loss: 0.6248
# Epoch 3/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.5767 - val_accuracy: 0.7987 - val_loss: 0.5106
# Epoch 4/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7934 - loss: 0.4842 - val_accuracy: 0.7987 - val_loss: 0.4509
# Epoch 5/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.4573 - val_accuracy: 0.7987 - val_loss: 0.4424
# Epoch 6/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7934 - loss: 0.4510 - val_accuracy: 0.7987 - val_loss: 0.4394
# Epoch 7/15
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.4472 - val_accuracy: 0.7987 - val_loss: 0.4374
# Epoch 8/15
# ...

# %%
loss_batch128, acc_batch128 = model_E.evaluate(x_test, y_test)

print("Accuracy :", acc_batch128)
print("Loss :", loss_batch128)
print("Training Time :", time_batch128)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8035 - loss: 0.4212
# Accuracy : 0.8034999966621399
# Loss : 0.4211789071559906
# Training Time : 7.7437474727630615

# %%
table = pd.DataFrame({
    "Batch Size": [8, 16, 32, 64, 128],
    "Accuracy": [acc_batch8,acc_batch16,acc_batch32,acc_batch64,acc_batch128],
    "Loss": [loss_batch8,loss_batch16,loss_batch32,loss_batch64,loss_batch128],
    "Training Time": [time_batch8,time_batch16,time_batch32,time_batch64,time_batch128]
})

print(table)
# Out:
#    Batch Size  Accuracy      Loss  Training Time
# 0           8    0.8380  0.399600      43.966745
# 1          16    0.8410  0.397977      29.750303
# 2          32    0.8330  0.404739      14.169677
# 3          64    0.8155  0.410338      10.273008
# 4         128    0.8035  0.421179       7.743747

# %% [markdown]
# Batch size 16 achieved the best balance between accuracy, loss, and training time.

# %% [markdown]
# #TASK-9

# %%
from keras.layers import Dropout

# %%
model = Sequential()
model.add(Dense(units=32,kernel_initializer='he_uniform',activation='relu',input_dim=10))
model.add(Dropout(0.2))
model.add(Dense(units=32,kernel_initializer='he_uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=32,kernel_initializer='he_uniform',activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1,kernel_initializer='he_uniform',activation='sigmoid'))

# %%
import time
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

start_time = time.time()
history = model.fit(x_train,y_train,validation_split=0.2,batch_size=32,epochs=50)
end_time = time.time()

time = end_time - start_time
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7588 - loss: 0.5648 - val_accuracy: 0.8044 - val_loss: 0.4583
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7877 - loss: 0.4932 - val_accuracy: 0.8031 - val_loss: 0.4376
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7912 - loss: 0.4713 - val_accuracy: 0.8125 - val_loss: 0.4283
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8000 - loss: 0.4614 - val_accuracy: 0.8194 - val_loss: 0.4203
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8020 - loss: 0.4490 - val_accuracy: 0.8275 - val_loss: 0.4130
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8050 - loss: 0.4432 - val_accuracy: 0.8313 - val_loss: 0.4062
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8130 - loss: 0.4315 - val_accuracy: 0.8413 - val_loss: 0.3984
# Epoch 8/50
# ...

# %%
loss, acc = model.evaluate(x_test, y_test)

print("Accuracy :", acc)
print("Loss :", loss)
print("Time :", time)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8660 - loss: 0.3418
# Accuracy : 0.8659999966621399
# Loss : 0.34183889627456665
# Time : 38.8466534614563

# %% [markdown]
# #TASK-10

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print("Accuracy :", accuracy)
print("Precision :", precision)
print("Recall :", recall)
print("F1 Score :", f1)
print("\nConfusion Matrix:\n", cm)
# Out:
# Accuracy : 0.866
# Precision : 0.7906976744186046
# Recall : 0.43256997455470736
# F1 Score : 0.5592105263157895
#
# Confusion Matrix:
#  [[1562   45]
#  [ 223  170]]

# %%
model.summary()
# Out:
# Model: "sequential_40"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_153 (Dense)               │ (None, 32)             │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_154 (Dense)               │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_155 (Dense)               │ (None, 32)             │         1,056 │
# ...
